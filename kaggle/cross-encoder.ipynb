# %%
# !pip install transformers torch
# !pip install pyvi
# !pip install sentence-transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 54.8 MB/s eta 0:00:0000:0100:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 53.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 8.7 MB/s eta 0:00:00
# ...

# %%
from pyvi.ViTokenizer import tokenize

def word_segment(text):
    text = tokenize(text.encode('utf-8').decode('utf-8'))

    return text

# %%
from sentence_transformers import CrossEncoder
model = CrossEncoder('cross-encoder/ms-marco-MiniLM-L-6-v2', max_length=512)
scores = model.predict([('What is the capital of France?', 'Paris is the capital of France.'), ('What is the capital of France?', 'How many people live in Berlin?')])
print(scores)
# Out:
# /opt/conda/lib/python3.10/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# 2024-06-22 17:56:42.632891: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-22 17:56:42.632990: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-22 17:56:42.751344: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
from sentence_transformers import CrossEncoder
import torch

model = CrossEncoder('cross-encoder/ms-marco-MiniLM-L-6-v2', max_length=512, default_activation_function=torch.nn.Sigmoid())
scores = model.predict([('Đi xe máy vi phạm nồng độ cồn bị phạt bao nhiêu', 'Mức xử phạt khi có nồng độ cồn trong máu và điều khiển xe máy'), 
                        ('Đi xe máy vi phạm nồng độ cồn bị phạt bao nhiêu', 'Uống rượu đến nồng độ cồn nào thì bị phạt'),
                        ('Đi xe máy vi phạm nồng độ cồn bị phạt bao nhiêu', 'Cơ quan có trách nhiệm điều động lực lượng phòng cháy chữa cháy'),
                        ('Ủy ban Quốc gia Ứng phó sự cố, thiên tai và Tìm kiếm Cứu nạn có trách nhiệm gì trong ứng phó sự cố chất thải?', 'Căn cứ Điều 21 Quy chế ứng phó sự cố chất thải Ban hành kèm theo Quyết định 09/2020/QĐ-TTg, Ủy ban Quốc gia Ứng phó sự cố, thiên tai và Tìm kiếm Cứu nạn có trách nhiệm: - Chỉ đạo xây dựng, thực hiện và kiểm tra việc thực hiện Kế hoạch ứng phó sự cố chất thải; kiểm tra và đôn đốc việc chuẩn bị và sẵn sàng tổ chức ứng phó sự cố; tổ chức huấn luyện, diễn tập ứng phó sự cố chất thải. - Chỉ đạo, trực tiếp tổ chức ứng phó sự cố chất thải theo Quy chế này.'),
                        ('Chính sách nội trú đối với người khuyết tật học 2 ngành của trường cao đẳng?', 'Theo Khoản 1 Điều 2 Quyết định 53/2015/QĐ-TTg thì bạn là người khuyết tật là đối tượng được hưởng chính sách nội trú khi học cao đẳng nghề. Theo Khoản 1 Điều 2 Thông tư liên tịch 12/2016/TTLT-BLĐTBXH-BGDĐT-BTC có quy định như sau: Trường hợp học sinh, sinh viên thuộc đối tượng được hưởng nhiều chính sách cùng lúc thì chỉ được hưởng 01 (một) chính sách cao nhất hoặc học đồng thời ở nhiều cơ sở giáo dục nghề nghiệp thì chỉ được hưởng chính sách ở 01 (một) cơ sở giáo dục nghề nghiệp hoặc cùng lúc học nhiều ngành, nghề, nhiều trình độ trong cùng một cơ sở giáo dục nghề nghiệp thì chỉ được hưởng chính sách 01 (một) lần trong toàn bộ thời gian học. Như vậy trường hợp của bạn học 2 ngành của cùng 1 trường cao đẳng nghề thì chỉ được hưởng chính sách 01 lần trong toàn bộ thời gian học.'),
                       ])
print(scores)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# [0.99654406 0.97599626 0.02017595 0.99971443 0.99967194]

# %%
# use this cross-encoder
from sentence_transformers import CrossEncoder
model = CrossEncoder('cross-encoder/ms-marco-MiniLM-L-6-v2', max_length=512, default_activation_function=torch.nn.Sigmoid())
scores = model.predict([(word_segment('Đi xe máy vi phạm nồng độ cồn bị phạt bao nhiêu'), word_segment('Mức xử phạt khi có nồng độ cồn trong máu và điều khiển xe máy')), 
                        (word_segment('Đi xe máy vi phạm nồng độ cồn bị phạt bao nhiêu'), word_segment('Uống rượu đến nồng độ cồn nào thì bị phạt')),
                        (word_segment('Đi xe máy vi phạm nồng độ cồn bị phạt bao nhiêu'), word_segment('Cơ quan có trách nhiệm điều động lực lượng phòng cháy chữa cháy')),
                        (word_segment('Đi xe máy vi phạm nồng độ cồn bị phạt bao nhiêu'), word_segment('Vi phạm nồng độ cồn khi điều khiển xe máy xử phạt bao nhiêu tiền')),
                        (word_segment('Ủy ban Quốc gia Ứng phó sự cố, thiên tai và Tìm kiếm Cứu nạn có trách nhiệm gì trong ứng phó sự cố chất thải?'), word_segment('Căn cứ Điều 21 Quy chế ứng phó sự cố chất thải Ban hành kèm theo Quyết định 09/2020/QĐ-TTg, Ủy ban Quốc gia Ứng phó sự cố, thiên tai và Tìm kiếm Cứu nạn có trách nhiệm: - Chỉ đạo xây dựng, thực hiện và kiểm tra việc thực hiện Kế hoạch ứng phó sự cố chất thải; kiểm tra và đôn đốc việc chuẩn bị và sẵn sàng tổ chức ứng phó sự cố; tổ chức huấn luyện, diễn tập ứng phó sự cố chất thải. - Chỉ đạo, trực tiếp tổ chức ứng phó sự cố chất thải theo Quy chế này.')),
                        (word_segment('Chính sách nội trú đối với người khuyết tật học 2 ngành của trường cao đẳng?'), word_segment('Theo Khoản 1 Điều 2 Quyết định 53/2015/QĐ-TTg thì bạn là người khuyết tật là đối tượng được hưởng chính sách nội trú khi học cao đẳng nghề. Theo Khoản 1 Điều 2 Thông tư liên tịch 12/2016/TTLT-BLĐTBXH-BGDĐT-BTC có quy định như sau: Trường hợp học sinh, sinh viên thuộc đối tượng được hưởng nhiều chính sách cùng lúc thì chỉ được hưởng 01 (một) chính sách cao nhất hoặc học đồng thời ở nhiều cơ sở giáo dục nghề nghiệp thì chỉ được hưởng chính sách ở 01 (một) cơ sở giáo dục nghề nghiệp hoặc cùng lúc học nhiều ngành, nghề, nhiều trình độ trong cùng một cơ sở giáo dục nghề nghiệp thì chỉ được hưởng chính sách 01 (một) lần trong toàn bộ thời gian học. Như vậy trường hợp của bạn học 2 ngành của cùng 1 trường cao đẳng nghề thì chỉ được hưởng chính sách 01 lần trong toàn bộ thời gian học.')),
                       ])
print(scores)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# [0.99516356 0.9414799  0.02188882 0.99958783 0.9994734  0.999368  ]

# %%
from sentence_transformers import CrossEncoder
import torch

model = CrossEncoder('cross-encoder/ms-marco-MiniLM-L-6-v2', max_length=512, default_activation_function=torch.nn.Sigmoid())
scores = model.predict([('How much is the penalty for riding a motorbike with an alcohol violation?', 'Penalties for having a blood alcohol concentration and driving a motorbike'), 
                        ('How much is the penalty for riding a motorbike with an alcohol violation?', 'Drinking alcohol up to any alcohol concentration is punishable'),
                        ('How much is the penalty for riding a motorbike with an alcohol violation?', 'The agency is responsible for mobilizing fire prevention and fighting forces'),
                        ('What responsibilities does the National Committee for Incident and Disaster Response and Search and Rescue have in responding to waste incidents?', 'Pursuant to Article 21 of the Regulation on response to waste incidents issued together with Decision 09/2020/QD-TTg, the National Committee for Incident and Disaster Response and Search and Rescue is responsible for: - Directing the construction Develop, implement and inspect the implementation of the Waste Incident Response Plan; inspect and urge preparation and readiness to organize incident response; Organize training and drills to respond to waste incidents. - Direct and directly organize waste incident response according to this Regulation.'),
                        ('Boarding policy for people with disabilities studying two majors at a college?', 'According to Clause 1, Article 2, Decision 53/2015/QD-TTg, people with disabilities are eligible for boarding policies when studying at vocational colleges. According to Clause 1, Article 2, Joint Circular 12/2016/TTLT-BLDTBXH-BGDĐT-BTC has the following regulations: In case students are eligible to enjoy many policies at the same time, they are only entitled to 01 (one) policy. ) the highest policy or studying at many vocational education institutions at the same time, are only entitled to the policy at 01 (one) vocational education institution or studying many majors, occupations, and levels at the same time at the same institution. Vocational education institutions are only entitled to enjoy the policy 01 (one) time during the entire study period. So, in case you study 2 majors of the same vocational college, you will only enjoy the policy once during the entire study period.'),
                       ])
print(scores)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# [8.4694070e-01 3.2738675e-03 1.3836845e-05 9.9993801e-01 9.9935478e-01]

# %%
import torch
from sentence_transformers import CrossEncoder
model = CrossEncoder('cross-encoder/ms-marco-MiniLM-L-6-v2', max_length=512, default_activation_function=torch.nn.Sigmoid())
scores = model.predict([(word_segment('Đi xe máy vi phạm nồng độ cồn bị phạt bao nhiêu tiền?'), word_segment('căn cứ 5 nghị định 100 2019 nđ cp 6 nghị định 100 2019 nđ cp sửa đổi bổ sung nghị định 123 2021 nđ cp quy định xử phạt vi phạm nồng độ cồn đối với xe máy xe ô tô tuỳ thuộc nồng độ cồn đo 100 mililít máu 1 lít khí thở cụ thể xử phạt vi phạm nồng độ cồn đối với xe máy phạt tiền 2 3 triệu đồng nồng độ cồn 50 miligam 100 mililít máu 0 25 miligam 1 lít khí thở tước giấy phép lái xe 10 12 phạt tiền 4 5 triệu đồng nồng độ cồn 50 miligam 80 miligam 100 mililít máu 0 25 miligam 0 4 miligam 1 lít khí thở tước giấy phép lái xe 16 18 phạt tiền 6 8 triệu đồng nồng độ cồn 80 miligam 100 mililít máu 0 4 miligam 1 lít khí thở tước giấy phép lái xe 22 24 xử phạt vi phạm nồng độ cồn xe ô tô phạt tiền 6 8 triệu đồng nồng độ cồn 50 miligam 100 mililít máu 0 25 miligam 1 lít khí thở tước giấy phép lái xe 10 12 phạt tiền 16 18 triệu đồng nồng độ cồn 50 miligam 80 miligam 100 mililít máu 0 25 miligam 0 4 miligam 1 lít khí thở tước giấy phép lái xe 16 18 phạt tiền 30 40 triệu đồng nồng độ cồn 80 miligam 100 mililít máu 0 4 miligam 1 lít khí thở tước giấy phép lái xe 22 24')), 
                        (word_segment('Đi xe máy vi phạm nồng độ cồn bị phạt bao nhiêu tiền?'), word_segment('căn cứ điểm c khoản 6 c khoản 7 e khoản 8 đ e g khoản 10 6 nghị định 100 2019 nđ cp quy định xử phạt điều khiển xe mô tô xe gắn máy kể cả xe máy điện xe tương tự xe mô tô xe tương tự xe gắn máy vi phạm quy tắc giao thông đường bộ xử phạt điều khiển xe mô tô xe gắn máy kể cả xe máy điện xe tương tự xe mô tô xe tương tự xe gắn máy vi phạm quy tắc giao thông đường bộ 6 phạt tiền 2 000 000 đồng 3 000 000 đồng đối với điều khiển xe thực hiện hành vi vi phạm c điều khiển xe đường máu hơi thở nồng độ cồn 50 miligam 100 mililít máu 0 25 miligam 1 lít khí thở 7 phạt tiền 4 000 000 đồng 5 000 000 đồng đối với điều khiển xe thực hiện hành vi vi phạm c điều khiển xe đường máu hơi thở nồng độ cồn 50 miligam 80 miligam 100 mililít máu 0 25 miligam 0 4 miligam 1 lít khí thở 8 phạt tiền 6 000 000 đồng 8 000 000 đồng đối với điều khiển xe thực hiện hành vi vi phạm e điều khiển xe đường máu hơi thở nồng độ cồn 80 miligam 100 mililít máu 0 4 miligam 1 lít khí thở 10 phạt tiền điều khiển xe thực hiện hành vi vi phạm áp dụng hình thức xử phạt bổ sung đ thực hiện hành vi quy định c khoản 6 tước quyền sử dụng giấy phép lái xe 10 12 e thực hiện hành vi quy định c khoản 7 tước quyền sử dụng giấy phép lái xe 16 18 g thực hiện hành vi quy định e g h i khoản 8 tước quyền sử dụng giấy phép lái xe 22 24')),
                        (word_segment('Đi xe máy vi phạm nồng độ cồn bị phạt bao nhiêu tiền?'), word_segment('căn cứ b khoản 2 21 nghị định 100 2019 nđ cp sửa đổi khoản 11 2 nghị định 123 2021 nđ cp quy định xử phạt hành vi vi phạm quy định điều kiện điều khiển xe cơ giới xử phạt hành vi vi phạm quy định điều kiện điều khiển xe cơ giới 2 phạt tiền 100 000 đồng 200 000 đồng đối với hành vi vi phạm a điều khiển xe mô tô xe gắn máy xe tương tự xe mô tô xe tương tự xe gắn máy giấy chứng nhận bảo hiểm trách nhiệm dân sự chủ xe cơ giới hiệu lực b điều khiển xe mô tô xe gắn máy xe tương tự xe mô tô xe tương tự xe gắn máy giấy đăng ký xe c điều khiển xe mô tô xe tương tự xe mô tô giấy phép lái xe trừ hành vi vi phạm quy định b khoản 5 c khoản 7')),
                        (word_segment('Ủy ban Quốc gia Ứng phó sự cố, thiên tai và Tìm kiếm Cứu nạn có trách nhiệm gì trong ứng phó sự cố chất thải?'), word_segment('Căn cứ Điều 21 Quy chế ứng phó sự cố chất thải Ban hành kèm theo Quyết định 09/2020/QĐ-TTg, Ủy ban Quốc gia Ứng phó sự cố, thiên tai và Tìm kiếm Cứu nạn có trách nhiệm: - Chỉ đạo xây dựng, thực hiện và kiểm tra việc thực hiện Kế hoạch ứng phó sự cố chất thải; kiểm tra và đôn đốc việc chuẩn bị và sẵn sàng tổ chức ứng phó sự cố; tổ chức huấn luyện, diễn tập ứng phó sự cố chất thải. - Chỉ đạo, trực tiếp tổ chức ứng phó sự cố chất thải theo Quy chế này.')),
                        (word_segment('Chính sách nội trú đối với người khuyết tật học 2 ngành của trường cao đẳng?'), word_segment('Theo Khoản 1 Điều 2 Quyết định 53/2015/QĐ-TTg thì bạn là người khuyết tật là đối tượng được hưởng chính sách nội trú khi học cao đẳng nghề. Theo Khoản 1 Điều 2 Thông tư liên tịch 12/2016/TTLT-BLĐTBXH-BGDĐT-BTC có quy định như sau: Trường hợp học sinh, sinh viên thuộc đối tượng được hưởng nhiều chính sách cùng lúc thì chỉ được hưởng 01 (một) chính sách cao nhất hoặc học đồng thời ở nhiều cơ sở giáo dục nghề nghiệp thì chỉ được hưởng chính sách ở 01 (một) cơ sở giáo dục nghề nghiệp hoặc cùng lúc học nhiều ngành, nghề, nhiều trình độ trong cùng một cơ sở giáo dục nghề nghiệp thì chỉ được hưởng chính sách 01 (một) lần trong toàn bộ thời gian học. Như vậy trường hợp của bạn học 2 ngành của cùng 1 trường cao đẳng nghề thì chỉ được hưởng chính sách 01 lần trong toàn bộ thời gian học.')),
                       ])
print(scores)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# [0.9952171  0.99363756 0.96448773 0.9994734  0.999368  ]

# %%
import torch
from sentence_transformers import CrossEncoder
model = CrossEncoder('cross-encoder/ms-marco-MiniLM-L-6-v2', max_length=512, default_activation_function=torch.nn.Sigmoid())
scores = model.predict([(word_segment('Ủy ban Quốc gia Ứng phó sự cố, thiên tai và Tìm kiếm Cứu nạn có trách nhiệm gì trong ứng phó sự cố chất thải?'), word_segment('Theo Khoản 1 Điều 2 Quyết định 53/2015/QĐ-TTg thì bạn là người khuyết tật là đối tượng được hưởng chính sách nội trú khi học cao đẳng nghề. Theo Khoản 1 Điều 2 Thông tư liên tịch 12/2016/TTLT-BLĐTBXH-BGDĐT-BTC có quy định như sau: Trường hợp học sinh, sinh viên thuộc đối tượng được hưởng nhiều chính sách cùng lúc thì chỉ được hưởng 01 (một) chính sách cao nhất hoặc học đồng thời ở nhiều cơ sở giáo dục nghề nghiệp thì chỉ được hưởng chính sách ở 01 (một) cơ sở giáo dục nghề nghiệp hoặc cùng lúc học nhiều ngành, nghề, nhiều trình độ trong cùng một cơ sở giáo dục nghề nghiệp thì chỉ được hưởng chính sách 01 (một) lần trong toàn bộ thời gian học. Như vậy trường hợp của bạn học 2 ngành của cùng 1 trường cao đẳng nghề thì chỉ được hưởng chính sách 01 lần trong toàn bộ thời gian học.')),
                        (word_segment('Chính sách nội trú đối với người khuyết tật học 2 ngành của trường cao đẳng?'), word_segment('Căn cứ Điều 21 Quy chế ứng phó sự cố chất thải Ban hành kèm theo Quyết định 09/2020/QĐ-TTg, Ủy ban Quốc gia Ứng phó sự cố, thiên tai và Tìm kiếm Cứu nạn có trách nhiệm: - Chỉ đạo xây dựng, thực hiện và kiểm tra việc thực hiện Kế hoạch ứng phó sự cố chất thải; kiểm tra và đôn đốc việc chuẩn bị và sẵn sàng tổ chức ứng phó sự cố; tổ chức huấn luyện, diễn tập ứng phó sự cố chất thải. - Chỉ đạo, trực tiếp tổ chức ứng phó sự cố chất thải theo Quy chế này.')),
                       ])
print(scores)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# [0.39171106 0.02677776]
